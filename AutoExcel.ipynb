# %%
import pandas as pd

# 读取第一个CSV文件
df1 = pd.read_csv('E:/pyitem/data/stone_tan/report1.csv')
# 读取第二个CSV文件
df2 = pd.read_csv('E:/pyitem/data/stone_tan/report2.csv')#财务

header1 = df1.columns.tolist()# 获取列名
header2 = df2.columns.tolist()
print(header1)
print(header2)

# 根据name列合并两个DataFrame
# 将"Leasing Contract Date"列转换为日期时间格式
df1['Leasing Contract Date 租赁合同开始时间'] = pd.to_datetime(df1['Leasing Contract Date 租赁合同开始时间'], format='%d/%m/%Y')

# 提取年份信息
df1['Year'] = df1['Leasing Contract Date 租赁合同开始时间'].dt.year
print(df1['Year'])

merged_df = pd.merge(df1, df2, left_on='Chinese Company Name 公司中文名字', right_on='Account: Chinese Company Name 公司中文名字', how='inner')
print(merged_df['Year'])
# merged_df = pd.merge(df1, df2, on='Account: Chinese Company Name 公司中文名字', how='inner')

# # 打印合并后的结果
# print(merged_df)
# Out:
# C:\Users\16835\AppData\Local\Temp\ipykernel_19440\2179198032.py:4: DtypeWarning: Columns (7,21,22,45,80,86,87,88,97,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('E:/pyitem/data/stone_tan/report1.csv')
# C:\Users\16835\AppData\Local\Temp\ipykernel_19440\2179198032.py:6: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('E:/pyitem/data/stone_tan/report2.csv')#财务
# ['Opportunity Name', 'Association Count', '合同金额', 'X2 Date', '授信Date', 'S3 Assigned Date', 'Prior Lease Date', 'Emily Comment', 'Recruitment Count', 'Wechat Story Count', 'Guihua Count', 'EIA Count', 'Rongyu Priority', 'Rongyu Common', 'Latest Rongyu Check Date', 'Rongyu Count', 'Guanlian Check Date', '环评/项目', '环评/项目CheckDate', 'BRAT Contact Classifier', 'Gift Count', 'IRR', 'BRAT Stage', 'Account Type', 'Related Company (关联公司）', '项目来源', 'Related Company Financial Check Date', '客户类型', 'Sunshine PPT Date', '业务类型', 'X2 Reason', 'Data Company 1 Fail Reason', 'Account Description', '国民经济行业分类 Secondary', '5 Million Lease', 'Employees', 'Sunshine Stage', '国民经济行业分类', 'Frequency Classifier', 'Last RS Yujingtong Date', 'Holding Company Country 控股公司国家', 'Project Investment Classifier', 'Machinery Amount', 'Machinery Description', 'Machinery Company Brands:', 'Machinery Classifier', 'Leasing Loyalty Classifier', 'Year of First Lease', 'First Leasing Company', 'Opportunity Count', 'Shareholder Details 股东信息', 'Website', 'Stock Exchange 交易所', 'Registration Date 设立时间', 'Billing Street', 'Registered Capital (万 RMB)', 'China Leasing Registration 动产融资统一登记', 'Leasing Amount (k) 租赁金额', 'Estimated Leasing Amount (k)', 'Qualifiers', 'Days Since Last Lease', 'Account Name', '1 Product  Detail 主题产品', 'Product Category 产品分类', 'Administrative Region 行政区', 'Opportunity ID', 'Account ID', 'CEO Name', 'Close Date (2)', 'Chinese Company Name 公司中文名字', 'Leasing Contract Date 租赁合同开始时间', 'Latest Leasing Contract Date 租赁合同开始时间', 'Missed Opportunity Details', 'Reason for Lost Opportunity', 'Sales Rep 客户经理', 'Stage Duration', 'Investment Project Details', 'Billing City', 'Industry', 'Industry Park Relation', 'Opportunity Contact', 'Shareholder Classifier', 'Billing State Classifier', 'Billing State/Province', 'Sales Rep', 'Last Campaign Date', 'Last Phone Call Date', 'Last Factory Visit Date', 'Last Stage Change Date', 'Latest 中登网 Date (风暴)', 'Current Leasing Company', 'Type', 'Lead Source', 'Lead Status 潜在客户情况', 'Amount Currency', 'Amount', 'Close Date', 'Next Step', 'Stage', 'Probability (%)', 'Fiscal Period', 'Age', 'Created Date', 'Opportunity Owner', 'Owner Role', 'Risk Storm Leasing Company', 'Winning Leasing Company']
# ['Account: Chinese Company Name 公司中文名字', 'Account: X2 Date', 'Account: Sales Rep 客户经理', 'Account: Sales Comment', 'Account: X2 Reason', 'Account: S3 Assigned Date', '净利润2022', 'Account: 项目来源', '净利率2022', '毛利率2022', '营收2022', 'Criteria: ID', 'QCC Pro 资产 Range', 'QCC Pro 亏损', 'QCC Pro Update Date', 'QCC Pro Revenue Range', 'Account: Data Company 1 Fail Reason', 'Account: First Leasing Company', 'Account: Year of First Lease', 'Account: Billing State Classifier', '毛利率2021', '资产负债率2021', '营收2021', '净利润2021', '净利率2021', 'Account: Account ID', 'Account: Account Name', 'Account: 客户类型', 'Account: 业务类型', 'Account: Administrative Region 行政区', 'Account: 国民经济行业分类 Secondary', 'Account: 5 Million Lease', 'Account: China Leasing Registration 动产融资统一登记', 'Criteria: Created Date', 'Account: Created Date', 'Account: Wechat Story Count', 'Account: Guihua Count', 'Account: Rongyu Count', 'Account: Land Count', 'Account: EIA Count', 'Account: Opportunity Count', 'Account: Registration Date 设立时间', 'Account: Latest 中登网 Date (风暴)', 'Account: Related Company Financial Check Date', 'Account: Related Company (关联公司）', 'Account: Guanlian Check Date', 'Account: 国民经济行业分类', 'Account: Sunshine Stage', 'Account: Stock Exchange 交易所', 'Account: Stock Code', 'Account: Billing State/Province', 'Account: Billing City', '详细产品', 'Account: 1 Product  Detail 主题产品', '营收2015', '营收2016', '营收2017', '营收2018', '营收2019', '营收2020', '净利率2015', '净利率2016', '净利率2017', '净利率2018', '净利率2019', '净利率2020', '毛利率2015', '毛利率2016', '毛利率2017', '毛利率2018', '毛利率2019', '毛利率2020']
# 0         2022.0
# 1         2022.0
# 2         2022.0
# 3         2022.0
# 4         2022.0
#            ...
# 108016    2017.0
# 108017    2020.0
# 108018    2019.0
# 108019    2019.0
# 108020    2018.0
# Name: Year, Length: 108021, dtype: float64
# 0        2022.0
# 1        2021.0
# 2        2021.0
# 3        2021.0
# 4        2022.0
#           ...
# 58374    2018.0
# 58375    2022.0
# 58376    2018.0
# 58377    2019.0
# 58378    2019.0
# Name: Year, Length: 58379, dtype: float64

# %%
# 将"Leasing Contract Date"列转换为日期时间格式
df1['Leasing Contract Date 租赁合同开始时间'] = pd.to_datetime(df1['Leasing Contract Date 租赁合同开始时间'], format='%d/%m/%Y')

# 提取年份信息
df1['Year'] = df1['Leasing Contract Date 租赁合同开始时间'].dt.year
print(df1['Year'])
# Out:
# 0         2022.0
# 1         2022.0
# 2         2022.0
# 3         2022.0
# 4         2022.0
#            ...
# 108016    2017.0
# 108017    2020.0
# 108018    2019.0
# 108019    2019.0
# 108020    2018.0
# Name: Year, Length: 108021, dtype: float64

# %%
# 设置筛选条件
condition1 = merged_df['Winning Leasing Company'] == 'Zhong Li 仲利国际租赁有限公司'
condition2 = merged_df['Year'].isin([2022,2023])
condition3 = ~merged_df['Shareholder Classifier'].isin(['Listed 上市公司', 'SOE 国有企业'])
condition4 = merged_df['Billing State Classifier'].isin(['JiangsuA','Jiangsu A','JiangsuB', 'Jiangsu B','Jiangsu','Zhejiang','Shanghai'])
# 根据筛选条件过滤行
filtered_rows = merged_df.loc[condition1 & condition2 & condition3 & condition4]

# # 打印结果DataFrame
# print(filtered_rows)

# 选择所需的列
selected_columns1 = filtered_rows[['Chinese Company Name 公司中文名字', 'Sales Rep 客户经理', '国民经济行业分类', 'Sunshine Stage', 'QCC Pro 亏损', '营收2021', '净利率2021', 'QCC Pro Revenue Range', '业务类型', 'X2 Reason', 'Opportunity Count','Estimated Leasing Amount (k)']]
selected_columns2 = filtered_rows[['Account: Account ID', 'Account: Account Name', 'Account: 业务类型', 'Billing State Classifier', 'Administrative Region 行政区']]

# 打印结果DataFrame
# print(selected_columns1)

# selected_columns1.to_csv('E:/pyitem/data/stone_tan/output1.csv', index=False,encoding='utf-8')
# selected_columns2.to_csv('E:/pyitem/data/stone_tan/output2.csv', index=False,encoding='utf-8')

# %%
# 设置筛选条件
conditions = [
    "(`Winning Leasing Company` == 'Zhong Li 仲利国际租赁有限公司')",
    "(Year in [2022, 2023])",
    "(~`Shareholder Classifier`.isin(['Listed 上市公司', 'SOE 国有企业']))",
    "(`Billing State Classifier`.isin(['JiangsuA', 'Jiangsu A', 'JiangsuB', 'Jiangsu B', 'Jiangsu', 'Zhejiang', 'Shanghai']))"
]

# 根据筛选条件过滤行
filtered_rows = merged_df.query(" and ".join(conditions))

# 选择所需的列
selected_columns1 = filtered_rows[['Chinese Company Name 公司中文名字', 'Sales Rep 客户经理', '国民经济行业分类', 'Sunshine Stage', 'QCC Pro 亏损', '营收2021', '净利率2021', 'QCC Pro Revenue Range', '业务类型', 'X2 Reason', 'Opportunity Count', 'Estimated Leasing Amount (k)']]
selected_columns2 = filtered_rows[['Account: Account ID', 'Account: Account Name', 'Account: 业务类型', 'Billing State Classifier', 'Administrative Region 行政区']]

# %%
import pandas as pd

#初始文件，修改索引列,格式转换
df1 = pd.read_csv('/content/Conley2 - 副本.csv',encoding = 'GBK')
# 将登记时间列转换为日期类型
df1["Latest 中登网 Date (风暴)"] = pd.to_datetime(df1["Latest 中登网 Date (风暴)"])
# 将日期类型的列转换为指定格式的字符串
df1["new_time"] = df1["Latest 中登网 Date (风暴)"].dt.strftime("%Y-%-m-%-d")
# # 输出结果
# 去除空行
df1 = df1.dropna(how='all')

# print(df1["new_time"])

#目标文件
df = pd.read_excel("/content/登记详细信息列表 (4).xls", sheet_name="融资租赁")
df["登记时间"] = pd.to_datetime(df["登记时间"])
df["time_new"] = df["登记时间"].dt.strftime("%Y-%-m-%-d")
# print(df["time_new"])

# %% [markdown]
# Test

# %%
import datetime

merged_df = pd.merge(df, df1, left_on="承租人名称（金融机构、企业、机关事业单位、其他）/\n字号名称（个体工商户）", right_on="Chinese Company Name 公司中文名字", how="inner")
print(merged_df["Chinese Company Name 公司中文名字"][0])

# 定义 datetime2
datetime2 = pd.to_datetime(merged_df["new_time"])

registration_types = []
time_new_values = []

# 根据"初始登记"值将"登记类型"列分割成多个列表
grouped_types = []
grouped_time_new = []
for i, row in merged_df.iterrows():
    reg_type = row["登记类型"]
    time_new = row["time_new"]
    if reg_type == "初始登记":
        if grouped_types:
            registration_types.append(grouped_types)
            time_new_values.append(grouped_time_new)
            grouped_types = []
            grouped_time_new = []
        grouped_types.append(reg_type)
        grouped_time_new.append([time_new])  # 将单个值包装在列表中
    else:
        grouped_types.append(reg_type)
        grouped_time_new[-1].append(time_new)  # 添加到最后一个列表中

# 添加最后一个列表
registration_types.append(grouped_types)
time_new_values.append(grouped_time_new)

# 将"登记类型"和"time_new"组合成字典
result = {}
for types, times in zip(registration_types, time_new_values):
    if len(types) == 1 and types[0] == "初始登记":
        if types[0] in result:
            result[types[0]].extend(times)
        else:
            result[types[0]] = times
    else:
        key = tuple(types)
        if key in result:
            result[key].extend(times)
        else:
            result[key] = times


# 输出结果
result_dict = {}
for key, value in result.items():
    length = len(key)
    if length in result_dict:
        result_dict[length][key] = value
    else:
        result_dict[length] = {key: value}

import pandas as pd

df_first = pd.DataFrame(columns=["Form Filler", "Leasing Time", "Leasing Value"])
df_last = pd.DataFrame(columns=["Form Filler", "Leasing Time", "Leasing Value"])

for length, result in result_dict.items():
    if length == 4:
        # print(f"字典长度为 {length}")

        for key, values in result.items():
            if '初始登记' in key:
                # print(key)
                converted_values = []
                for sublist in values:
                    converted_sublist = [datetime.datetime.strptime(date_str, '%Y-%m-%d') for date_str in sublist]
                    converted_values.append(converted_sublist)

                # 遍历转换后的值
                for sublist in converted_values:
                    for date in sublist:
                        # 遍历 datetime2 的每个元素进行比较
                        found_match = False
                        for dt in datetime2:
                            if date > dt:
                                date1 = date.strftime('%Y-%m-%d')
                                print("Leasing Time:", date1)
                                found_match = True
                                break  # 找到匹配后立即终止内部循环

                        if found_match:
                            merged_df["time_new"] = pd.to_datetime(merged_df["time_new"])
                            date1_str = pd.to_datetime(date1).strftime('%Y-%m-%d')
                            filtered_row = merged_df[merged_df["time_new"].dt.strftime('%Y-%m-%d').str.match(date1_str)]

                            if not filtered_row.empty:
                                leasing_value = filtered_row["租赁财产价值"].values[0]
                                leasing_value /= 1000  # 将 leasing_value 的值除以 1000
                                form_filler = filtered_row["填表人"].values[0]
                                # print("Leasing Value:", leasing_value)
                                # print("Form Filler:", form_filler)

                                df_first = df_first.append(
                                    {"Form Filler": form_filler, "Leasing Time": date1, "Leasing Value": leasing_value},
                                    ignore_index=True
                                )

    else:
        for key, values in result.items():
            if "注销融资" not in key:
                # print(key)
                converted_values = []
                for sublist in values:
                    converted_sublist = [datetime.datetime.strptime(date_str, '%Y-%m-%d') for date_str in sublist]
                    last_value = converted_sublist[-1]  # 获取子列表中的最后一个数值
                    first_value = converted_sublist[0]
                    converted_values.append([last_value])  # 将最后一个数值作为单个元素的列表添加到新列表中

                # 遍历转换后的值
                for sublist in converted_values:
                    for date_value in sublist:
                        # 遍历 datetime2 的每个元素进行比较
                        found_match = False
                        for dt in datetime2:
                            if date_value > dt:
                                date3 = date_value.strftime('%Y-%m-%d')
                                found_match = True
                                break  # 找到匹配后立即终止内部循环
                        if found_match:
                            merged_df["time_new"] = pd.to_datetime(merged_df["time_new"])
                            date3_str = pd.to_datetime(date3).strftime('%Y-%m-%d')
                            first_date = datetime.datetime.strptime(values[0][0], '%Y-%m-%d')
                            date4_str = first_date.strftime('%Y-%m-%d')
                            # print("Leasing Time:", date4_str)
                            filtered_row1 = merged_df[merged_df["time_new"].dt.strftime('%Y-%m-%d').str.match(date3_str)]
                            filtered_row2 = merged_df[merged_df["time_new"].dt.strftime('%Y-%m-%d').str.match(date4_str)]
                            if not filtered_row1.empty and not filtered_row2.empty:
                                leasing_value = filtered_row1["租赁财产价值"].values[0]
                                leasing_value /= 1000  # 将 leasing_value 的值除以 1000
                                form_filler = filtered_row1["填表人"].values[0]
                                # print("Leasing Value:", leasing_value)
                                # print("Form Filler:", form_filler)

                                df_last = df_last.append(
                                    {"Form Filler": form_filler, "Leasing Time": date4_str, "Leasing Value": leasing_value},
                                    ignore_index=True
                                )

# 调整列顺序
df_first = df_first[["Form Filler", "Leasing Time", "Leasing Value"]]
df_last = df_last[["Form Filler", "Leasing Time", "Leasing Value"]]

print("df_first:")
print(df_first)
print("df_last:")
print(df_last)

# %% [markdown]
# Final

# %%
import datetime

merged_df = pd.merge(df, df1, left_on="承租人名称（金融机构、企业、机关事业单位、其他）/\n字号名称（个体工商户）", right_on="Chinese Company Name 公司中文名字", how="inner")
print(merged_df["Chinese Company Name 公司中文名字"][0])

datetime2 = pd.to_datetime(merged_df["new_time"])

registration_types = []
time_new_values = []

# 根据"初始登记"值将"登记类型"列分割成多个列表
grouped_types = []
grouped_time_new = []
for i, row in merged_df.iterrows():
    reg_type = row["登记类型"]
    time_new = row["time_new"]
    if reg_type == "初始登记":
        if grouped_types:
            registration_types.append(grouped_types)
            time_new_values.append(grouped_time_new)
            grouped_types = []
            grouped_time_new = []
        grouped_types.append(reg_type)
        grouped_time_new.append([time_new])  # 将单个值包装在列表中
    else:
        grouped_types.append(reg_type)
        grouped_time_new[-1].append(time_new)  # 添加到最后一个列表中

# 添加最后一个列表
registration_types.append(grouped_types)
time_new_values.append(grouped_time_new)

# 将"登记类型"和"time_new"组合成字典
result = {}
for types, times in zip(registration_types, time_new_values):
    if len(types) == 1 and types[0] == "初始登记":
        if types[0] in result:
            result[types[0]].extend(times)
        else:
            result[types[0]] = times
    else:
        key = tuple(types)
        if key in result:
            result[key].extend(times)
        else:
            result[key] = times

# 输出结果
result_dict = {}
for key, value in result.items():
    length = len(key)
    if length in result_dict:
        result_dict[length][key] = value
    else:
        result_dict[length] = {key: value}


df_first = pd.DataFrame(columns=["填表人", "租赁时间", "租赁价值"])
df_last = pd.DataFrame(columns=["填表人", "租赁时间", "租赁价值"])

for length, result in result_dict.items():
    if length == 4:
        for key, values in result.items():
            if '初始登记' in key:
                converted_values = []
                for sublist in values:
                    converted_sublist = [datetime.datetime.strptime(date_str, '%Y-%m-%d') for date_str in sublist]
                    converted_values.append(converted_sublist)

                for sublist in converted_values:
                    for date in sublist:
                        found_match = False
                        for dt in datetime2:
                            if date > dt:
                                date1 = date.strftime('%Y-%m-%d')
                                found_match = True
                                break

                        if found_match:
                            merged_df["time_new"] = pd.to_datetime(merged_df["time_new"])
                            date1_str = pd.to_datetime(date1).strftime('%Y-%m-%d')
                            filtered_row = merged_df[merged_df["time_new"].dt.strftime('%Y-%m-%d').str.match(date1_str)]

                            if not filtered_row.empty:
                                leasing_value = filtered_row["租赁财产价值"].values[0]
                                leasing_value /= 1000
                                form_filler = filtered_row["填表人"].values[0]

                                df_first = pd.concat([df_first, pd.DataFrame({"填表人": [form_filler],
                                                                             "租赁时间": [date1],
                                                                             "租赁价值": [leasing_value]})],
                                                     ignore_index=True)

    else:
        for key, values in result.items():
            if "注销融资" not in key:
                converted_values = []
                for sublist in values:
                    converted_sublist = [datetime.datetime.strptime(date_str, '%Y-%m-%d') for date_str in sublist]
                    last_value = converted_sublist[-1]
                    first_value = converted_sublist[0]
                    converted_values.append([last_value])

                for sublist in converted_values:
                    for date_value in sublist:
                        found_match = False
                        for dt in datetime2:
                            if date_value > dt:
                                date3 = date_value.strftime('%Y-%m-%d')
                                found_match = True
                                break

                        if found_match:
                            merged_df["time_new"] = pd.to_datetime(merged_df["time_new"])
                            date3_str = pd.to_datetime(date3).strftime('%Y-%m-%d')
                            first_date = datetime.datetime.strptime(values[0][0], '%Y-%m-%d')
                            date4_str = first_date.strftime('%Y-%m-%d')
                            filtered_row1 = merged_df[merged_df["time_new"].dt.strftime('%Y-%m-%d').str.match(date3_str)]
                            filtered_row2 = merged_df[merged_df["time_new"].dt.strftime('%Y-%m-%d').str.match(date4_str)]
                            if not filtered_row1.empty and not filtered_row2.empty:
                                leasing_value = filtered_row1["租赁财产价值"].values[0]
                                leasing_value /= 1000
                                form_filler = filtered_row1["填表人"].values[0]
                                df_last = pd.concat([df_last, pd.DataFrame({"填表人": [form_filler],
                                                                           "租赁时间": [date4_str],
                                                                           "租赁价值": [leasing_value]})],
                                                   ignore_index=True)

# 美化
df_first = df_first.groupby(["租赁时间", "填表人"], as_index=False)["租赁价值"].sum()
df_last = df_last.groupby(["租赁时间", "填表人"], as_index=False)["租赁价值"].sum()

df_first = df_first[["填表人", "租赁时间", "租赁价值"]]
df_last = df_last[["填表人", "租赁时间", "租赁价值"]]

# 修改日期列的格式为月/日/年，并删除日期和月份前的前导零
df_first["租赁时间"] = pd.to_datetime(df_first["租赁时间"]).dt.strftime("%-m/%-d/%Y")
df_last["租赁时间"] = pd.to_datetime(df_last["租赁时间"]).dt.strftime("%-m/%-d/%Y")

print("仅有初始登记:")
print(df_first)
print("多个登记类型:")
print(df_last)
